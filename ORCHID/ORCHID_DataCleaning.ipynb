# %%
# Importing the libraries
import pandas as pd
import numpy as np
import os
# Ignore all warnings
import warnings
warnings.filterwarnings('ignore')

# %%
cwd = os.getcwd() 
folder_path = os.path.join(cwd, 'RawData')

# %%
# reading csv files and storing as a dataframe
df_abgevents = pd.read_csv(os.path.join(folder_path,"ABGevents.csv"))
df_calc_death = pd.read_csv(os.path.join(folder_path,"calc_deaths.csv"))
df_referral = pd.read_csv(os.path.join(folder_path,"referrals.csv"))
df_culture_events = pd.read_csv(os.path.join(folder_path,"CultureEvents.csv"))
df_fluid_balance_events = pd.read_csv(os.path.join(folder_path,"FluidBalanceEvents.csv"))
df_hemo=pd.read_csv(os.path.join(folder_path,"HemoEvents.csv"))
df_serology=pd.read_csv(os.path.join(folder_path,"SerologyEvents.csv"))
df_chem=pd.read_csv(os.path.join(folder_path,"ChemistryEvents.csv"))
df_cbc=pd.read_csv(os.path.join(folder_path,"CBCEvents.csv"))

# %% [markdown]
# ### Referral DataFrame Cleaning:

# %%
# check number of rows of referral dataframe
df_abgevents.shape[0]
# Out:
# 2288828

# %%
# looking at the data
df_referral.head(5)
# Out:
#     OPO     PatientID   Age Gender                      Race   HospitalID  \
# 0  OPO1  OPO1_P320866  62.0      M         White / Caucasian  OPO1_H23456
# 1  OPO1  OPO1_P549364  14.0      F         White / Caucasian  OPO1_H11908
# 2  OPO1  OPO1_P536997  55.0      M         White / Caucasian  OPO1_H23111
# 3  OPO1  OPO1_P463285  48.0      F  Black / African American  OPO1_H26589
# 4  OPO1  OPO1_P284978  80.0      F         White / Caucasian   OPO1_H5832
#
#    brain_death Cause_of_Death_OPO Cause_of_Death_UNOS Mechanism_of_Death  ...  \
# 0        False                NaN         Head Trauma                NaN  ...
# 1        False                NaN                 NaN                NaN  ...
# 2        False                NaN          CVA/Stroke         ICH/Stroke  ...
# 3        False                NaN              Anoxia     Cardiovascular  ...
# 4        False                NaN                 NaN                NaN  ...
#
#   Referral_Year Procured_Year outcome_heart  outcome_liver  \
# 0          2018           NaN           NaN            NaN
# 1          2021           NaN           NaN            NaN
# 2          2015           NaN           NaN            NaN
# 3          2019           NaN           NaN            NaN
# 4          2018           NaN           NaN            NaN
#
#    outcome_kidney_left  outcome_kidney_right  outcome_lung_left  \
# 0                  NaN                   NaN                NaN
# 1                  NaN                   NaN                NaN
# 2                  NaN                   NaN                NaN
# 3                  NaN                   NaN                NaN
# 4                  NaN                   NaN                NaN
#
#    outcome_lung_right  outcome_intestine  outcome_pancreas
# 0                 NaN                NaN               NaN
# 1                 NaN                NaN               NaN
# 2                 NaN                NaN               NaN
# 3                 NaN                NaN               NaN
# 4                 NaN                NaN               NaN
#
# [5 rows x 38 columns]

# %%
# checking the information of the dataframe
df_referral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133101 entries, 0 to 133100
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   OPO                     133101 non-null  object
#  1   PatientID               133101 non-null  object
#  2   Age                     133017 non-null  float64
#  3   Gender                  133040 non-null  object
#  4   Race                    133101 non-null  object
#  5   HospitalID              133101 non-null  object
#  6   brain_death             133101 non-null  bool
#  7   Cause_of_Death_OPO      32396 non-null   object
#  8   Cause_of_Death_UNOS     103283 non-null  object
#  9   Mechanism_of_Death      98533 non-null   object
#  10  Circumstances_of_Death  98588 non-null   object
#  11  ABO_BloodType           18201 non-null   object
#  12  ABO_Rh                  8743 non-null    object
#  13  HeightIn                98500 non-null   float64
#  14  WeightKg                123346 non-null  float64
#  15  approached              133101 non-null  bool
#  16  authorized              133101 non-null  bool
#  17  procured                133101 non-null  bool
#  18  transplanted            133101 non-null  bool
#  19  Tissue_Referral         133101 non-null  bool
#  20  Eye_Referral            133101 non-null  bool
#  21  time_asystole           89415 non-null   object
#  22  time_brain_death        11855 non-null   object
#  23  time_referred           133101 non-null  object
#  24  time_approached         16191 non-null   object
#  25  time_authorized         11665 non-null   object
#  26  time_procured           9502 non-null    object
#  27  Referral_DayofWeek      133101 non-null  object
#  28  Referral_Year           133101 non-null  int64
#  29  Procured_Year           9543 non-null    float64
#  30  outcome_heart           3690 non-null    object
#  31  outcome_liver           7902 non-null    object
#  32  outcome_kidney_left     8801 non-null    object
#  33  outcome_kidney_right    8811 non-null    object
#  34  outcome_lung_left       3406 non-null    object
#  35  outcome_lung_right      3446 non-null    object
#  36  outcome_intestine       368 non-null     object
#  37  outcome_pancreas        1676 non-null    object
# dtypes: bool(7), float64(4), int64(1), object(26)
# memory usage: 32.4+ MB

# %%
# List of columns to convert data type from object to timestamp
columns_to_convert = ['time_asystole', 'time_brain_death', 'time_referred', 'time_approached','time_authorized','time_procured']

# Apply pd.to_datetime to each column
for col in columns_to_convert:
    df_referral[col] = pd.to_datetime(df_referral[col], errors='coerce')

#List of columns to convert data type from float to int
col_toConvert_int = ['Procured_Year','Age']
# Apply astype() to convert
for colint in col_toConvert_int:
    df_referral[colint] = df_referral[colint].astype('Int64')

# %%
# checking for duplicate records 
print("Duplicate Rows:\n", df_referral.duplicated().sum())
# Out:
# Duplicate Rows:
#  0

# %%
# Checking for the value counts of 'mechanism_of_death' column for cleanup
df_referral['Mechanism_of_Death'].value_counts()
# Out:
# Mechanism_of_Death
# Cardiovascular                       27267
# Natural Causes                       25882
# ICH/Stroke                           16476
# None of the Above                     8757
# Blunt Injury                          8313
# Drug Intoxication                     3285
# Gun Shot Wound                        1992
# Asphyxiation                          1939
# Intracranial Hemmorrhage / Stroke     1311
# Death from Natural Causes              890
# Seizure                                775
# Drug / Intoxication                    546
# Drowning                               507
# Gunshot Wound                          297
# Other                                  112
# Stab                                    76
# Electrical                              51
# Sudden Infant Death                     41
# None of the above                       16
# Name: count, dtype: int64

# %%
# Created dictionary mapping to replace similar values
replace_dict = {
    'Gun Shot Wound': 'Gunshot Wound',
    'Drug / Intoxication': 'Drug Intoxication',
    'None of the Above': 'None of the above',
    'ICH/Stroke':'Intracranial Hemmorrhage / Stroke',
    'Death from Natural Causes':'Natural Causes'
}

df_referral['Mechanism_of_Death'].replace(replace_dict, inplace=True)

# %%
# This step shows the updated value counts for 'mechanism_of_death' column
df_referral['Mechanism_of_Death'].value_counts()
# Out:
# Mechanism_of_Death
# Cardiovascular                       27267
# Natural Causes                       26772
# Intracranial Hemmorrhage / Stroke    17787
# None of the above                     8773
# Blunt Injury                          8313
# Drug Intoxication                     3831
# Gunshot Wound                         2289
# Asphyxiation                          1939
# Seizure                                775
# Drowning                               507
# Other                                  112
# Stab                                    76
# Electrical                              51
# Sudden Infant Death                     41
# Name: count, dtype: int64

# %%
# Checking for the value counts of 'circumstances_of_death' column for cleanup
df_referral['Circumstances_of_Death'].value_counts()
# Out:
# Circumstances_of_Death
# Natural Causes                60700
# None of the Above             17859
# Accident, Non-MVA              6446
# MVA                            5045
# Death from Natural Causes      3470
# Suicide                        2282
# Homicide                       1293
# Motor Vehicle Accident          481
# Non-Motor Vehicle Accident      336
# Alleged Suicide                 293
# Alleged Homicide                141
# Child Abuse                     127
# Other                            95
# Alleged Child Abuse              20
# Name: count, dtype: int64

# %%
# Created dictionary mapping to replace similar values
replace_dict_cod = {
    'Natural Causes': 'Death from Natural Causes',
    'Accident, Non-MVA': 'Non-Motor Vehicle Accident',
    'MVA': 'Motor Vehicle Accident'   
}

df_referral['Circumstances_of_Death'].replace(replace_dict_cod, inplace=True)

# %%
# This step shows the updated value counts for 'circumstances_of_death' column
df_referral['Circumstances_of_Death'].value_counts()
# Out:
# Circumstances_of_Death
# Death from Natural Causes     64170
# None of the Above             17859
# Non-Motor Vehicle Accident     6782
# Motor Vehicle Accident         5526
# Suicide                        2282
# Homicide                       1293
# Alleged Suicide                 293
# Alleged Homicide                141
# Child Abuse                     127
# Other                            95
# Alleged Child Abuse              20
# Name: count, dtype: int64

# %%
df_referral['time_procured'].value_counts()
# Out:
# time_procured
# 2035-04-28 16:52:00    2
# 2032-11-07 21:59:00    2
# 2036-03-27 17:52:00    2
# 2031-04-19 19:54:00    2
# 2035-03-14 07:18:00    1
#                       ..
# 2031-01-02 21:50:00    1
# 2030-05-15 18:04:00    1
# 2032-07-09 03:39:00    1
# 2032-10-05 01:03:00    1
# 2036-10-30 17:23:00    1
# Name: count, Length: 7901, dtype: int64

# %%
# Checking bloodtype and rh column to see the count of not null values before merging both the columns
df_referral[(df_referral['ABO_BloodType'].notna() & df_referral['ABO_Rh'].notna())].shape
# Out:
# (8739, 38)

# %%
# Code to merge both the columns when the values are not null, This step ignores the cases where bloodtype is null and rh is not null
df_referral.loc[df_referral['ABO_BloodType'].notna() & df_referral['ABO_Rh'].notna(), 'ABO_BloodType'] = (
    df_referral['ABO_BloodType'] + '-' + df_referral['ABO_Rh']
)

# %%
# Checking to verify the unique values after merging the columns
df_referral['ABO_BloodType'].unique()
# Out:
# array([nan, 'O-Positive', 'A1-Positive', 'A-Positive', 'A2-Positive',
#        'A1-Negative', 'A2B-Positive', 'B-Positive', 'O-Negative',
#        'A1B-Positive', 'AB-Positive', 'B-Negative', 'A1B-Negative',
#        'A-Negative', 'AB-Negative', 'A2-Negative', 'A', 'O', 'B', 'A1',
#        'AB', 'A2B-Negative', 'A2B', 'A2', 'A1B', 'A1-Positive ',
#        'A-Positive ', 'B-Positive ', 'A-Negative ', 'B-Negative ',
#        'AB-Positive ', 'O-Positive ', 'A1-Negative ', 'O-Negative ',
#        'AB-Negative ', 'A1B-Positive ', 'A2-Positive ', 'A2-Negative ',
#        'A2B-Positive ', 'A1B-Negative ', 'A2B-Negative '], dtype=object)

# %%
# Deleting the columns 'ABO_Rh' and 'Referral_DayofWeek'. 'abo_rh' values are merged so its duplicate. 
#Dropped 'Referral_DayofWeek' column as we did not find any significance towards our objective.

df_referral.drop(columns=['ABO_Rh','Referral_DayofWeek'], inplace= True)

# %%
df_referral['WeightKg'].max()
# Out:
# 9101.0

# %%
df_referral.query('WeightKg > 650')
# Out:
#          OPO     PatientID  Age Gender                      Race   HospitalID  \
# 9882    OPO1   OPO1_P26310   55      F                  Hispanic   OPO1_H4303
# 28246   OPO1   OPO1_P32277   46      F         White / Caucasian  OPO1_H20923
# 31121   OPO1  OPO1_P836782   40      M         White / Caucasian   OPO1_H8351
# 54984   OPO3  OPO3_P499799   47      F         White / Caucasian   OPO3_H6081
# 85221   OPO4  OPO4_P752787   73      M         White / Caucasian  OPO4_H33509
# 106820  OPO5  OPO5_P249805   15      M         White / Caucasian  OPO5_H10831
# 111858  OPO6  OPO6_P327644   80      M         White / Caucasian   OPO6_H2155
# 119824  OPO6  OPO6_P371686   73      F         White / Caucasian   OPO6_H8991
# 120226  OPO6  OPO6_P578203   27      M  Black / African American  OPO6_H11154
# 123267  OPO6  OPO6_P721934   38      M         White / Caucasian  OPO6_H22175
# 132012  OPO6  OPO6_P986975   80      M         White / Caucasian    OPO6_H591
#
#         brain_death            Cause_of_Death_OPO Cause_of_Death_UNOS  \
# 9882          False                           NaN                 NaN
# 28246         False                           NaN               Other
# 31121         False                           NaN         Head Trauma
# 54984         False  Respiratory - Other, specify               Other
# 85221         False                           NaN           ICB / ICH
# 106820        False                           NaN         Head Trauma
# 111858        False                        Sepsis               Other
# 119824        False                Other, specify              Anoxia
# 120226         True                           NaN              Anoxia
# 123267        False                           NaN              Anoxia
# 132012        False  Respiratory - Other, specify              Anoxia
#
#                        Mechanism_of_Death  ... Referral_Year Procured_Year  \
# 9882                                  NaN  ...          2020          <NA>
# 28246                                 NaN  ...          2021          <NA>
# 31121                                 NaN  ...          2020          <NA>
# 54984                   None of the above  ...          2021          <NA>
# 85221   Intracranial Hemmorrhage / Stroke  ...          2020          <NA>
# 106820                       Blunt Injury  ...          2020          <NA>
# 111858                     Natural Causes  ...          2017          <NA>
# 119824                     Natural Causes  ...          2015          <NA>
# 120226                     Cardiovascular  ...          2015          <NA>
# 123267                  Drug Intoxication  ...          2016          <NA>
# 132012                     Natural Causes  ...          2015          <NA>
#
#         outcome_heart  outcome_liver  outcome_kidney_left  \
# 9882              NaN            NaN                  NaN
# 28246             NaN            NaN                  NaN
# 31121             NaN            NaN                  NaN
# 54984             NaN            NaN                  NaN
# 85221             NaN            NaN                  NaN
# 106820            NaN            NaN                  NaN
# 111858            NaN            NaN                  NaN
# 119824            NaN            NaN                  NaN
# 120226            NaN            NaN                  NaN
# 123267            NaN            NaN                  NaN
# 132012            NaN            NaN                  NaN
#
#         outcome_kidney_right  outcome_lung_left  outcome_lung_right  \
# 9882                     NaN                NaN                 NaN
# 28246                    NaN                NaN                 NaN
# 31121                    NaN                NaN                 NaN
# 54984                    NaN                NaN                 NaN
# 85221                    NaN                NaN                 NaN
# 106820                   NaN                NaN                 NaN
# 111858                   NaN                NaN                 NaN
# 119824                   NaN                NaN                 NaN
# 120226                   NaN                NaN                 NaN
# 123267                   NaN                NaN                 NaN
# 132012                   NaN                NaN                 NaN
#
#         outcome_intestine  outcome_pancreas
# 9882                  NaN               NaN
# 28246                 NaN               NaN
# 31121                 NaN               NaN
# 54984                 NaN               NaN
# 85221                 NaN               NaN
# 106820                NaN               NaN
# 111858                NaN               NaN
# 119824                NaN               NaN
# 120226                NaN               NaN
# 123267                NaN               NaN
# 132012                NaN               NaN
#
# [11 rows x 36 columns]

# %%
# Converting all weight values above 650kg to null. Since normal weight of person could not exceed more than that as per our search.
df_referral['WeightKg'] = df_referral['WeightKg'].apply(lambda x: np.nan if x > 650 else x)

# %%
# rounding the weight column values to 2 decimal places
df_referral['WeightKg'] = df_referral['WeightKg'].round(2)

# %%
df_referral['HeightIn'].max()
# Out:
# 1752.0

# %%
df_referral.query('HeightIn > 108')
# Out:
#          OPO     PatientID  Age Gender                      Race   HospitalID  \
# 67      OPO1  OPO1_P189494   73      M         White / Caucasian  OPO1_H28513
# 320     OPO1  OPO1_P266640   69      F         White / Caucasian   OPO1_H1793
# 388     OPO1  OPO1_P587625   65      F  Black / African American  OPO1_H28513
# 707     OPO1  OPO1_P111783   44      M         White / Caucasian  OPO1_H30962
# 810     OPO1  OPO1_P527371   77      F                  Hispanic  OPO1_H28513
# ...      ...           ...  ...    ...                       ...          ...
# 110053  OPO5  OPO5_P122278   54      F  Black / African American   OPO5_H2402
# 110170  OPO5  OPO5_P934760   65      M         White / Caucasian  OPO5_H12973
# 111295  OPO6  OPO6_P195992   68      M         White / Caucasian  OPO6_H14168
# 114281  OPO6   OPO6_P84410   42      M         White / Caucasian   OPO6_H8991
# 120172  OPO6  OPO6_P902461   37      M         White / Caucasian  OPO6_H14168
#
#         brain_death        Cause_of_Death_OPO Cause_of_Death_UNOS  \
# 67            False                       NaN              Anoxia
# 320           False                       NaN              Anoxia
# 388           False                       NaN         Head Trauma
# 707           False                       NaN                 NaN
# 810           False                       NaN                 NaN
# ...             ...                       ...                 ...
# 110053        False                       NaN                 NaN
# 110170        False               RES - other                 NaN
# 111295        False                       NaN          CVA/Stroke
# 114281        False  Cardiac - Other, specify              Anoxia
# 120172        False                       NaN         Head Trauma
#
#                        Mechanism_of_Death  ... Referral_Year Procured_Year  \
# 67                         Cardiovascular  ...          2015          <NA>
# 320                     None of the above  ...          2016          <NA>
# 388     Intracranial Hemmorrhage / Stroke  ...          2015          <NA>
# 707                                   NaN  ...          2021          <NA>
# 810                                   NaN  ...          2021          <NA>
# ...                                   ...  ...           ...           ...
# 110053                                NaN  ...          2021          <NA>
# 110170                                NaN  ...          2021          <NA>
# 111295  Intracranial Hemmorrhage / Stroke  ...          2015          <NA>
# 114281                     Natural Causes  ...          2015          <NA>
# 120172                       Blunt Injury  ...          2021          <NA>
#
#         outcome_heart  outcome_liver  outcome_kidney_left  \
# 67                NaN            NaN                  NaN
# 320               NaN            NaN                  NaN
# 388               NaN            NaN                  NaN
# 707               NaN            NaN                  NaN
# 810               NaN            NaN                  NaN
# ...               ...            ...                  ...
# 110053            NaN            NaN                  NaN
# 110170            NaN            NaN                  NaN
# 111295            NaN            NaN                  NaN
# 114281            NaN            NaN                  NaN
# 120172            NaN            NaN                  NaN
#
#         outcome_kidney_right  outcome_lung_left  outcome_lung_right  \
# 67                       NaN                NaN                 NaN
# 320                      NaN                NaN                 NaN
# 388                      NaN                NaN                 NaN
# 707                      NaN                NaN                 NaN
# 810                      NaN                NaN                 NaN
# ...                      ...                ...                 ...
# 110053                   NaN                NaN                 NaN
# 110170                   NaN                NaN                 NaN
# 111295                   NaN                NaN                 NaN
# 114281                   NaN                NaN                 NaN
# 120172                   NaN                NaN                 NaN
#
#         outcome_intestine  outcome_pancreas
# 67                    NaN               NaN
# 320                   NaN               NaN
# 388                   NaN               NaN
# 707                   NaN               NaN
# 810                   NaN               NaN
# ...                   ...               ...
# 110053                NaN               NaN
# 110170                NaN               NaN
# 111295                NaN               NaN
# 114281                NaN               NaN
# 120172                NaN               NaN
#
# [199 rows x 36 columns]

# %%
# Converting all height values above 108inch to null. Since height of person can not exceed more than that as per our search.
df_referral['HeightIn'] = df_referral['HeightIn'].apply(lambda x: np.nan if x > 108 else x)

# %%
# rounding the height column values to 2 decimal places
df_referral['HeightIn'] = df_referral['HeightIn'].round(2)

# %%
# The process of procurement between January 1, 2015 and December 31, 2021. We noticed outliers before and after the mentioned date 
# in 'procured_year' column.- 10 rows
df_referral.loc[(df_referral['Procured_Year'] < 2015) | (df_referral['Procured_Year'] > 2021)]
# Out:
#          OPO     PatientID  Age Gender                      Race   HospitalID  \
# 33285   OPO2  OPO2_P754522   45      M  Black / African American   OPO2_H5806
# 35187   OPO2  OPO2_P105623   66      M         White / Caucasian  OPO2_H11956
# 35334   OPO2  OPO2_P888977   62      F         White / Caucasian  OPO2_H11956
# 45356   OPO2  OPO2_P691827   36      M         White / Caucasian  OPO2_H15401
# 49512   OPO3  OPO3_P893473   21      M         White / Caucasian   OPO3_H4291
# 50300   OPO3   OPO3_P87321   31      F         White / Caucasian   OPO3_H4291
# 108156  OPO5  OPO5_P437885   49      M         White / Caucasian   OPO5_H6087
# 109893  OPO5  OPO5_P544793   71      F         White / Caucasian   OPO5_H6087
# 113737  OPO6  OPO6_P512017    1      F         White / Caucasian   OPO6_H6602
# 117329  OPO6  OPO6_P319706   46      M         White / Caucasian  OPO6_H16901
#
#         brain_death Cause_of_Death_OPO       Cause_of_Death_UNOS  \
# 33285          True                NaN                    Anoxia
# 35187          True                NaN               Head Trauma
# 35334          True                NaN                    Anoxia
# 45356          True                NaN                    Anoxia
# 49512         False                NaN                       NaN
# 50300         False                NaN                       NaN
# 108156        False         An - other                    Anoxia
# 109893         True                NaN  Cerebrovascular / Stroke
# 113737        False                NaN                    Anoxia
# 117329         True                NaN               Head Trauma
#
#                        Mechanism_of_Death  ... Referral_Year Procured_Year  \
# 33285                   Drug Intoxication  ...          2021          2022
# 35187                        Blunt Injury  ...          2021          2022
# 35334                   Drug Intoxication  ...          2021          2022
# 45356                        Asphyxiation  ...          2021          2022
# 49512                                 NaN  ...          2015          1987
# 50300                                 NaN  ...          2015          1987
# 108156                     Cardiovascular  ...          2021          2022
# 109893  Intracranial Hemmorrhage / Stroke  ...          2021          2022
# 113737                           Drowning  ...          2021          2022
# 117329                       Blunt Injury  ...          2021          2022
#
#                  outcome_heart  outcome_liver  \
# 33285                      NaN   Transplanted
# 35187   Recovered for Research   Transplanted
# 35334                      NaN            NaN
# 45356   Recovered for Research   Transplanted
# 49512                      NaN            NaN
# 50300                      NaN            NaN
# 108156                     NaN            NaN
# 109893                     NaN   Transplanted
# 113737                     NaN            NaN
# 117329                     NaN   Transplanted
#
#                                   outcome_kidney_left  \
# 33285                                             NaN
# 35187                                    Transplanted
# 35334   Recovered for Transplant but not Transplanted
# 45356                                    Transplanted
# 49512                                             NaN
# 50300                                             NaN
# 108156                                   Transplanted
# 109893                         Recovered for Research
# 113737                                   Transplanted
# 117329                                   Transplanted
#
#                                  outcome_kidney_right  outcome_lung_left  \
# 33285                                             NaN                NaN
# 35187                                    Transplanted                NaN
# 35334   Recovered for Transplant but not Transplanted                NaN
# 45356                                    Transplanted                NaN
# 49512                                             NaN                NaN
# 50300                                             NaN                NaN
# 108156                                   Transplanted                NaN
# 109893                         Recovered for Research                NaN
# 113737                                   Transplanted                NaN
# 117329                                   Transplanted                NaN
#
#         outcome_lung_right       outcome_intestine        outcome_pancreas
# 33285                  NaN                     NaN                     NaN
# 35187                  NaN                     NaN                     NaN
# 35334                  NaN                     NaN                     NaN
# 45356                  NaN  Recovered for Research  Recovered for Research
# 49512                  NaN                     NaN                     NaN
# 50300                  NaN                     NaN                     NaN
# 108156                 NaN                     NaN                     NaN
# 109893                 NaN                     NaN  Recovered for Research
# 113737                 NaN                     NaN                     NaN
# 117329                 NaN                     NaN                     NaN
#
# [10 rows x 36 columns]

# %%
# Changing the outliers to null in 'procured_year' column
df_referral.loc[(df_referral['Procured_Year'] < 2015) | (df_referral['Procured_Year'] > 2021), 
       'Procured_Year'] = np.nan

# %%
# Procured step is before transplant so when transplant column has value True, procured has to be True. There is one patient who
# does not satify the condition

df_referral.loc[(df_referral['transplanted'] == True) & (df_referral['procured'] == False)]
# Out:
#         OPO     PatientID  Age Gender      Race   HospitalID  brain_death  \
# 20119  OPO1  OPO1_P188776   60      M  Hispanic  OPO1_H26589        False
#
#       Cause_of_Death_OPO Cause_of_Death_UNOS  \
# 20119          ICB / ICH               Other
#
#                       Mechanism_of_Death  ... Referral_Year Procured_Year  \
# 20119  Intracranial Hemmorrhage / Stroke  ...          2015          <NA>
#
#        outcome_heart  outcome_liver  outcome_kidney_left  \
# 20119            NaN            NaN                  NaN
#
#        outcome_kidney_right  outcome_lung_left  outcome_lung_right  \
# 20119          Transplanted                NaN                 NaN
#
#        outcome_intestine  outcome_pancreas
# 20119                NaN               NaN
#
# [1 rows x 36 columns]

# %%
# Updating procured to True based on the condition for the above patient
df_referral.loc[(df_referral['transplanted'] == True) & (df_referral['procured'] == False), 
       'procured'] = True

# %%
# When procured_year column has year, we assume that the procurement happened so the procured column has to be True. 
# There are 39 patients who does not satisfy that condition.
df_referral.loc[(df_referral['Procured_Year'].notna()) & (df_referral['procured'] == False)]
# Out:
#          OPO     PatientID  Age Gender                      Race   HospitalID  \
# 385     OPO1  OPO1_P746312   26      M  Black / African American  OPO1_H27265
# 1181    OPO1  OPO1_P194150    0      M                  Hispanic  OPO1_H15318
# 2139    OPO1  OPO1_P413576   79      F         White / Caucasian  OPO1_H21231
# 2829    OPO1  OPO1_P716240   67      F  Black / African American  OPO1_H22406
# 4285    OPO1  OPO1_P602137   64      M         White / Caucasian  OPO1_H30669
# 8350    OPO1  OPO1_P315126   67      M         White / Caucasian    OPO1_H475
# 9470    OPO1  OPO1_P800088   39      M         White / Caucasian  OPO1_H25074
# 11065   OPO1  OPO1_P307722   58      F         White / Caucasian   OPO1_H4959
# 11755   OPO1  OPO1_P159786   47      M         White / Caucasian  OPO1_H23111
# 12844   OPO1  OPO1_P311956    0      F         White / Caucasian  OPO1_H26720
# 17566   OPO1  OPO1_P342307   31      M  Black / African American  OPO1_H30152
# 18913   OPO1  OPO1_P432621    0      F                  Hispanic  OPO1_H26720
# 20452   OPO1  OPO1_P325218    0      F         White / Caucasian  OPO1_H26184
# 21111   OPO1  OPO1_P438910   48      M         White / Caucasian  OPO1_H21467
# 24333   OPO1  OPO1_P657575   56      M  Black / African American  OPO1_H25074
# 24483   OPO1  OPO1_P221266    0      F         White / Caucasian  OPO1_H23267
# 27193   OPO1  OPO1_P698628   35      F         White / Caucasian   OPO1_H2662
# 27301   OPO1  OPO1_P400132   71      M         White / Caucasian  OPO1_H23456
# 30283   OPO1  OPO1_P595435   20      F         White / Caucasian  OPO1_H22535
# 30293   OPO1  OPO1_P652273   74      F  Black / African American    OPO1_H383
# 30525   OPO1  OPO1_P492936   62      M         White / Caucasian  OPO1_H28487
# 31141   OPO1  OPO1_P432530   46      M         White / Caucasian   OPO1_H8351
# 40084   OPO2  OPO2_P660026   33      F  Black / African American   OPO2_H5806
# 48730   OPO3  OPO3_P551906   72      M         White / Caucasian  OPO3_H11531
# 53026   OPO3  OPO3_P449835    0      F         White / Caucasian   OPO3_H4291
# 57672   OPO3  OPO3_P497075   12      F  Black / African American  OPO3_H10734
# 58658   OPO3  OPO3_P816086    0      F         White / Caucasian   OPO3_H4291
# 58812   OPO3  OPO3_P965549   20      F         White / Caucasian  OPO3_H10734
# 59640   OPO3   OPO3_P39074   68      M         White / Caucasian   OPO3_H4291
# 61544   OPO4  OPO4_P402389   44      M         White / Caucasian   OPO4_H8282
# 62638   OPO4  OPO4_P716416   39      M         White / Caucasian   OPO4_H2979
# 72398   OPO4  OPO4_P918649   50      M         White / Caucasian  OPO4_H30877
# 83227   OPO4   OPO4_P51271   35      M         White / Caucasian  OPO4_H13778
# 85054   OPO4  OPO4_P858564   76      M         White / Caucasian  OPO4_H30877
# 104236  OPO5  OPO5_P196007   14      M         White / Caucasian   OPO5_H8332
# 107563  OPO5  OPO5_P198689   52      M         White / Caucasian   OPO5_H1925
# 130377  OPO6  OPO6_P674864   57      F         White / Caucasian   OPO6_H2791
# 130552  OPO6  OPO6_P740569   43      F         White / Caucasian   OPO6_H2791
# 131495  OPO6  OPO6_P528908   43      M                  Hispanic  OPO6_H22175
#
#         brain_death        Cause_of_Death_OPO Cause_of_Death_UNOS  \
# 385            True                       NaN              Anoxia
# 1181          False                       NaN                 NaN
# 2139           True  Cardiac - Other, specify               Other
# 2829           True                       NaN          CVA/Stroke
# 4285           True                       NaN          CVA/Stroke
# 8350           True                       NaN              Anoxia
# 9470           True                       NaN              Anoxia
# 11065          True                       NaN              Anoxia
# 11755          True                       NaN          CVA/Stroke
# 12844         False              Fetal Demise               Other
# 17566         False                       NaN              Anoxia
# 18913         False            Other, specify               Other
# 20452         False               Prematurity               Other
# 21111          True  Cardiac - Other, specify              Anoxia
# 24333          True                       NaN              Anoxia
# 24483         False                       NaN                 NaN
# 27193         False                       NaN              Anoxia
# 27301          True                       NaN         Head Trauma
# 30283          True                       GSW         Head Trauma
# 30293          True  Cardiac - Other, specify               Other
# 30525          True                       NaN          CVA/Stroke
# 31141         False                       NaN         Head Trauma
# 40084          True                       NaN         Head Trauma
# 48730          True                       NaN              Anoxia
# 53026         False            Other, specify               Other
# 57672          True                       NaN              Anoxia
# 58658         False                       NaN              Anoxia
# 58812         False                       NaN              Anoxia
# 59640         False                       NaN              Anoxia
# 61544          True                       NaN              Anoxia
# 62638         False                       NaN              Anoxia
# 72398          True                       NaN              Anoxia
# 83227          True                       NaN              Anoxia
# 85054          True                       NaN              Anoxia
# 104236        False                       NaN              Anoxia
# 107563        False                  TR - MVA                 NaN
# 130377         True  Cardiac - Other, specify              Anoxia
# 130552         True  Cardiac - Other, specify               Other
# 131495         True                       NaN              Anoxia
#
#                        Mechanism_of_Death  ... Referral_Year Procured_Year  \
# 385                        Cardiovascular  ...          2017          2017
# 1181                                  NaN  ...          2017          2017
# 2139    Intracranial Hemmorrhage / Stroke  ...          2016          2016
# 2829    Intracranial Hemmorrhage / Stroke  ...          2018          2018
# 4285    Intracranial Hemmorrhage / Stroke  ...          2016          2016
# 8350                       Cardiovascular  ...          2018          2018
# 9470                       Cardiovascular  ...          2019          2019
# 11065                      Cardiovascular  ...          2019          2019
# 11755   Intracranial Hemmorrhage / Stroke  ...          2015          2015
# 12844                      Natural Causes  ...          2016          2016
# 17566                      Cardiovascular  ...          2016          2016
# 18913                   None of the above  ...          2015          2015
# 20452                   None of the above  ...          2018          2018
# 21111                      Cardiovascular  ...          2018          2018
# 24333                      Cardiovascular  ...          2018          2018
# 24483                                 NaN  ...          2021          2021
# 27193                      Cardiovascular  ...          2020          2020
# 27301                   None of the above  ...          2015          2015
# 30283                       Gunshot Wound  ...          2016          2016
# 30293                        Asphyxiation  ...          2016          2016
# 30525   Intracranial Hemmorrhage / Stroke  ...          2015          2015
# 31141                        Blunt Injury  ...          2021          2021
# 40084                        Blunt Injury  ...          2021          2021
# 48730                      Cardiovascular  ...          2021          2021
# 53026                      Natural Causes  ...          2020          2020
# 57672                        Asphyxiation  ...          2015          2015
# 58658                      Natural Causes  ...          2016          2016
# 58812                   None of the above  ...          2019          2019
# 59640                      Cardiovascular  ...          2020          2020
# 61544                      Cardiovascular  ...          2015          2015
# 62638                      Cardiovascular  ...          2015          2015
# 72398                      Cardiovascular  ...          2018          2018
# 83227                      Cardiovascular  ...          2020          2020
# 85054                      Cardiovascular  ...          2020          2020
# 104236                     Natural Causes  ...          2019          2019
# 107563                                NaN  ...          2020          2020
# 130377                     Cardiovascular  ...          2018          2018
# 130552                     Cardiovascular  ...          2019          2019
# 131495                       Blunt Injury  ...          2019          2019
#
#                  outcome_heart                                  outcome_liver  \
# 385                        NaN                                            NaN
# 1181    Recovered for Research                         Recovered for Research
# 2139                       NaN  Recovered for Transplant but not Transplanted
# 2829                       NaN                                            NaN
# 4285                       NaN                                            NaN
# 8350    Recovered for Research                                            NaN
# 9470    Recovered for Research  Recovered for Transplant but not Transplanted
# 11065                      NaN                                            NaN
# 11755                      NaN                                            NaN
# 12844                      NaN                                            NaN
# 17566                      NaN                                            NaN
# 18913   Recovered for Research                         Recovered for Research
# 20452   Recovered for Research                                            NaN
# 21111                      NaN                                            NaN
# 24333                      NaN                                            NaN
# 24483   Recovered for Research                                            NaN
# 27193                      NaN  Recovered for Transplant but not Transplanted
# 27301                      NaN                         Recovered for Research
# 30283                      NaN                         Recovered for Research
# 30293                      NaN                                            NaN
# 30525                      NaN                                            NaN
# 31141   Recovered for Research                                            NaN
# 40084                      NaN                                            NaN
# 48730                      NaN                                            NaN
# 53026                      NaN                                            NaN
# 57672                      NaN                                            NaN
# 58658   Recovered for Research                         Recovered for Research
# 58812                      NaN                         Recovered for Research
# 59640                      NaN                                            NaN
# 61544                      NaN                         Recovered for Research
# 62638                      NaN                                            NaN
# 72398                      NaN                                            NaN
# 83227                      NaN                                            NaN
# 85054                      NaN                                            NaN
# 104236                     NaN                                            NaN
# 107563                     NaN                                            NaN
# 130377                     NaN                                            NaN
# 130552                     NaN                                            NaN
# 131495                     NaN                                            NaN
#
#                                   outcome_kidney_left  \
# 385                                               NaN
# 1181                                              NaN
# 2139                                              NaN
# 2829                                              NaN
# 4285                           Recovered for Research
# 8350                                              NaN
# 9470                                              NaN
# 11065                                             NaN
# 11755                                             NaN
# 12844                                             NaN
# 17566                                             NaN
# 18913                                             NaN
# 20452                          Recovered for Research
# 21111                                             NaN
# 24333                                             NaN
# 24483                                             NaN
# 27193   Recovered for Transplant but not Transplanted
# 27301                                             NaN
# 30283                                             NaN
# 30293                                             NaN
# 30525                                             NaN
# 31141                                             NaN
# 40084                                             NaN
# 48730                                             NaN
# 53026                          Recovered for Research
# 57672                                             NaN
# 58658                          Recovered for Research
# 58812                                             NaN
# 59640                                             NaN
# 61544                          Recovered for Research
# 62638                                             NaN
# 72398                                             NaN
# 83227                                             NaN
# 85054                                             NaN
# 104236                                            NaN
# 107563                                            NaN
# 130377                                            NaN
# 130552                                            NaN
# 131495                         Recovered for Research
#
#                                  outcome_kidney_right       outcome_lung_left  \
# 385                            Recovered for Research                     NaN
# 1181                                              NaN  Recovered for Research
# 2139                                              NaN                     NaN
# 2829                                              NaN                     NaN
# 4285                           Recovered for Research                     NaN
# 8350                                              NaN                     NaN
# 9470                                              NaN                     NaN
# 11065                                             NaN                     NaN
# 11755                                             NaN  Recovered for Research
# 12844                                             NaN  Recovered for Research
# 17566                                             NaN                     NaN
# 18913                                             NaN  Recovered for Research
# 20452                          Recovered for Research  Recovered for Research
# 21111                                             NaN  Recovered for Research
# 24333                                             NaN                     NaN
# 24483                                             NaN  Recovered for Research
# 27193   Recovered for Transplant but not Transplanted                     NaN
# 27301                          Recovered for Research  Recovered for Research
# 30283                                             NaN                     NaN
# 30293                                             NaN                     NaN
# 30525                                             NaN                     NaN
# 31141                                             NaN  Recovered for Research
# 40084                                             NaN                     NaN
# 48730                                             NaN                     NaN
# 53026                          Recovered for Research                     NaN
# 57672                                             NaN                     NaN
# 58658                          Recovered for Research  Recovered for Research
# 58812                                             NaN                     NaN
# 59640                                             NaN                     NaN
# 61544                          Recovered for Research  Recovered for Research
# 62638                                             NaN                     NaN
# 72398                                             NaN  Recovered for Research
# 83227                                             NaN                     NaN
# 85054                                             NaN                     NaN
# 104236                                            NaN                     NaN
# 107563                                            NaN                     NaN
# 130377                                            NaN                     NaN
# 130552                                            NaN                     NaN
# 131495                         Recovered for Research                     NaN
#
#             outcome_lung_right  outcome_intestine        outcome_pancreas
# 385                        NaN                NaN                     NaN
# 1181    Recovered for Research                NaN  Recovered for Research
# 2139    Recovered for Research                NaN                     NaN
# 2829                       NaN                NaN                     NaN
# 4285                       NaN                NaN                     NaN
# 8350                       NaN                NaN                     NaN
# 9470                       NaN                NaN                     NaN
# 11065                      NaN                NaN                     NaN
# 11755   Recovered for Research                NaN  Recovered for Research
# 12844   Recovered for Research                NaN  Recovered for Research
# 17566                      NaN                NaN                     NaN
# 18913   Recovered for Research                NaN  Recovered for Research
# 20452   Recovered for Research                NaN  Recovered for Research
# 21111   Recovered for Research                NaN                     NaN
# 24333                      NaN                NaN                     NaN
# 24483   Recovered for Research                NaN                     NaN
# 27193                      NaN                NaN                     NaN
# 27301   Recovered for Research                NaN                     NaN
# 30283                      NaN                NaN                     NaN
# 30293                      NaN                NaN                     NaN
# 30525                      NaN                NaN                     NaN
# 31141   Recovered for Research                NaN                     NaN
# 40084                      NaN                NaN                     NaN
# 48730                      NaN                NaN                     NaN
# 53026                      NaN                NaN  Recovered for Research
# 57672                      NaN                NaN                     NaN
# 58658   Recovered for Research                NaN                     NaN
# 58812                      NaN                NaN                     NaN
# 59640                      NaN                NaN                     NaN
# 61544   Recovered for Research                NaN                     NaN
# 62638                      NaN                NaN                     NaN
# 72398   Recovered for Research                NaN                     NaN
# 83227                      NaN                NaN                     NaN
# 85054                      NaN                NaN                     NaN
# 104236                     NaN                NaN                     NaN
# 107563                     NaN                NaN                     NaN
# 130377                     NaN                NaN                     NaN
# 130552                     NaN                NaN                     NaN
# 131495                     NaN                NaN                     NaN
#
# [39 rows x 36 columns]

# %%
# Updating procured to True when procured_year column has year value.
df_referral.loc[(df_referral['Procured_Year'].notna()) & (df_referral['procured'] == False), 
       'procured'] = True
